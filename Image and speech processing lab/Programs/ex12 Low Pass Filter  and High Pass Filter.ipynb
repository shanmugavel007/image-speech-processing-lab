# %% [markdown]
# ## Ex12 Low Pass Filter  and High Pass Filter

# %% [markdown]
# ### High Pass Filter

# %%
import numpy as np
import scipy.signal as sg
import matplotlib.pyplot as plt
import librosa
from scipy.signal import butter,filtfilt
d_file = "./auds/set2.wav"
d, sr = librosa.load(d_file,8000)
t=np.linspace(0,len(d)/sr,len(d))
plt.plot(t,d, lw=1)
plt.xlabel('Time(s)')
plt.ylabel('Amplitude')
plt.title('Original speech file')
plt.grid(True)
plt.show()



b, a = sg.butter(4, 2000. / (sr / 2.), 'high')
d_fil = sg.filtfilt(b, a, d)
#plotting signal
fig, ax = plt.subplots(1, 1, figsize=(6, 3))
#equal sized arrays
t = np.linspace(0., len(d) / sr, len(d))
#plotting signal with line width =1
ax.plot(t, d, lw=1)
#plotting filtered signal with line width=1
ax.plot(t, d_fil, lw=1)
plt.xlabel('Time(s)')
plt.title('High pass filter - Filtered signal(show in orange color)')
plt.grid(True)
plt.show()
# Out:
# <ipython-input-1-98d17158889e>:7: FutureWarning: Pass sr=8000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   d, sr = librosa.load(d_file,8000)

# %% [markdown]
# ### Low Pass Filter

# %%
import numpy as np
import scipy.signal as sg
import matplotlib.pyplot as plt
import librosa
from scipy.signal import butter,filtfilt
d_file = "./auds/speech.wav"
d, sr = librosa.load(d_file,8000)
print(d)


d_file = "./auds/set2.wav"
d, sr = librosa.load(d_file,8000)
t=np.linspace(0,len(d)/sr,len(d))
plt.plot(t,d, lw=1)
plt.xlabel('Time(s)')
plt.ylabel('Amplitude')
plt.title('Original speech file')
plt.grid(True)
plt.show()



b, a = sg.butter(4, 500. / (sr / 2.), 'low')
d_fil = sg.filtfilt(b, a, d)
#plotting signal
fig, ax = plt.subplots(1, 1, figsize=(6, 3))
#equal sized arrays
t = np.linspace(0., len(d) / sr, len(d))
#plotting signal with line width =1
ax.plot(t, d, lw=1)
#plotting filtered signal with line width=1
ax.plot(t, d_fil, lw=1)
plt.xlabel('Time(s)')
plt.title('Low pass filter - Filtered signal(show in orange color)')
plt.grid(True)
plt.show()
# Out:
# <ipython-input-2-37f2acd3e7d6>:7: FutureWarning: Pass sr=8000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   d, sr = librosa.load(d_file,8000)
# <ipython-input-2-37f2acd3e7d6>:12: FutureWarning: Pass sr=8000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   d, sr = librosa.load(d_file,8000)
# [-0.01359191 -0.01232275  0.00308965 ...  0.00519403  0.00740799
#   0.06478132]
