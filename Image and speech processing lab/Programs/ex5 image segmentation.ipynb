# %% [markdown]
# ## EX5 Image Segmentation

# %% [markdown]
# ### Implementation

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline
# Read in the image
image = plt.imread('./imgs/butterfly.jpg')
# Change color to RGB (from BGR)
print(image.shape)
plt.subplot(121)
plt.imshow(image)
plt.title("Orginal Image")
# Reshaping the image into a 2D array of pixels and 3 color values (RGB)
pixel_vals = image.reshape((-1,3))
# Convert to float type
pixel_vals = np.float32(pixel_vals)

criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 100, 0.85)
retval, labels, centers = cv2.kmeans(pixel_vals, 3, None, criteria, 10,cv2.KMEANS_RANDOM_CENTERS)
centers = np.uint8(centers)
segmented_data = centers[labels.flatten()]
segmented_image = segmented_data.reshape((image.shape))
print(segmented_image.shape)
plt.subplot(122)
plt.imshow(segmented_image)
plt.title("Clustered Image")
plt.show()
# Out:
# (183, 275, 3)
# (183, 275, 3)

# %%
print(image)
# Out:
# [[[122 103  47]
#   [121 105  46]
#   [122 106  47]
#   ...
#   [133  91  67]
#   [127  85  61]
#   [117  75  51]]
#
#  [[121 104  48]
#   [121 104  48]
#   [122 106  47]
#   ...
#   [140  98  74]
#   [135  93  69]
#   [127  85  61]]
#
#  [[121 104  48]
#   [122 105  49]
#   [123 107  48]
#   ...
#   [141  99  75]
#   [137  95  71]
#   [131  89  65]]
#
#  ...
#
#  [[157  95  82]
#   [161  95  83]
#   [156  83  74]
#   ...
#   [135  83  62]
#   [135  83  62]
#   [135  83  62]]
#
#  [[146  90  73]
#   [144  87  70]
#   [138  77  59]
#   ...
#   [135  83  62]
#   [135  83  62]
#   [135  83  62]]
#
#  [[116  66  43]
#   [114  64  41]
#   [116  64  42]
#   ...
#   [134  82  61]
#   [134  82  61]
#   [134  82  61]]]

# %%
pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 1.10.0
# anaconda-project                   0.8.3
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# asn1crypto                         1.4.0
# astroid                            2.4.2
# astropy                            4.0.2
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              20.3.0
# audioread                          3.0.0
# autopep8                           1.5.4
# Babel                              2.8.1
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.1
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# bcrypt                             3.2.0
# beautifulsoup4                     4.9.3
# bitarray                           1.6.1
# bkcharts                           0.2
# bleach                             3.2.1
# bokeh                              2.2.3
# boto                               2.49.0
# Bottleneck                         1.3.2
# brotlipy                           0.7.0
# certifi                            2020.6.20
# cffi                               1.14.3
# chardet                            3.0.4
# click                              7.1.2
# cloudpickle                        1.6.0
# clyent                             1.2.2
# colorama                           0.4.4
# comtypes                           1.1.7
# conda                              4.12.0
# conda-build                        3.20.5
# conda-package-handling             1.7.2
# conda-verify                       3.4.2
# contextlib2                        0.6.0.post1
# cryptography                       3.1.1
# cycler                             0.10.0
# Cython                             0.29.21
# cytoolz                            0.11.0
# dask                               2.30.0
# decorator                          4.4.2
# defusedxml                         0.6.0
# diff-match-patch                   20200713
# distributed                        2.30.1
# docutils                           0.16
# entrypoints                        0.3
# et-xmlfile                         1.0.1
# fastcache                          1.1.0
# filelock                           3.0.12
# flake8                             3.8.4
# Flask                              1.1.2
# fsspec                             0.8.3
# future                             0.18.2
# gevent                             20.9.0
# glob2                              0.7
# greenlet                           0.4.17
# h5py                               2.10.0
# HeapDict                           1.0.1
# html5lib                           1.1
# idna                               2.10
# imageio                            2.9.0
# imagesize                          1.2.0
# importlib-metadata                 2.0.0
# iniconfig                          1.1.1
# intervaltree                       3.1.0
# ipykernel                          5.3.4
# ipython                            7.19.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.5.1
# isort                              5.6.4
# itsdangerous                       1.1.0
# jdcal                              1.4.1
# jedi                               0.17.1
# Jinja2                             2.11.2
# joblib                             0.17.0
# json5                              0.9.5
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter-client                     6.1.7
# jupyter-console                    6.2.0
# jupyter-core                       4.6.3
# jupyterlab                         2.2.6
# jupyterlab-pygments                0.1.2
# jupyterlab-server                  1.2.0
# keyring                            21.4.0
# kiwisolver                         1.3.0
# lazy-object-proxy                  1.4.3
# libarchive-c                       4.0
# librosa                            0.9.2
# llvmlite                           0.34.0
# locket                             0.2.0
# lxml                               4.6.1
# MarkupSafe                         1.1.1
# matplotlib                         3.3.2
# mccabe                             0.6.1
# menuinst                           1.4.16
# mistune                            0.8.4
# mkl-fft                            1.2.0
# mkl-random                         1.1.1
# mkl-service                        2.3.0
# mock                               4.0.2
# more-itertools                     8.6.0
# mpmath                             1.1.0
# msgpack                            1.0.0
# multipledispatch                   0.6.0
# navigator-updater                  0.2.1
# nbclient                           0.5.1
# nbconvert                          6.0.7
# nbformat                           5.0.8
# nest-asyncio                       1.4.2
# networkx                           2.5
# nltk                               3.5
# nose                               1.3.7
# notebook                           6.1.4
# numba                              0.51.2
# numexpr                            2.7.1
# numpy                              1.19.2
# numpydoc                           1.1.0
# olefile                            0.46
# openpyxl                           3.0.5
# packaging                          20.4
# pandas                             1.1.3
# pandocfilters                      1.4.3
# paramiko                           2.7.2
# parso                              0.7.0
# partd                              1.1.0
# path                               15.0.0
# pathlib2                           2.3.5
# pathtools                          0.1.2
# patsy                              0.5.1
# pep8                               1.7.1
# pexpect                            4.8.0
# pickleshare                        0.7.5
# Pillow                             8.0.1
# pip                                20.2.4
# pkginfo                            1.6.1
# pluggy                             0.13.1
# ply                                3.11
# pooch                              1.6.0
# prometheus-client                  0.8.0
# prompt-toolkit                     3.0.8
# psutil                             5.7.2
# py                                 1.9.0
# pycodestyle                        2.6.0
# pycosat                            0.6.3
# pycparser                          2.20
# pycurl                             7.43.0.6
# pydocstyle                         5.1.1
# pyflakes                           2.2.0
# Pygments                           2.7.2
# pylint                             2.6.0
# PyNaCl                             1.4.0
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          19.1.0
# pyparsing                          2.4.7
# pyreadline                         2.1
# pyrsistent                         0.17.3
# PySocks                            1.7.1
# pytest                             0.0.0
# python-dateutil                    2.8.1
# python-jsonrpc-server              0.4.0
# python-language-server             0.35.1
# pytz                               2020.1
# PyWavelets                         1.1.1
# pywin32                            227
# pywin32-ctypes                     0.2.0
# pywinpty                           0.5.7
# PyYAML                             5.3.1
# pyzmq                              19.0.2
# QDarkStyle                         2.8.1
# QtAwesome                          1.0.1
# qtconsole                          4.7.7
# QtPy                               1.9.0
# regex                              2020.10.15
# requests                           2.24.0
# resampy                            0.4.0
# rope                               0.18.0
# Rtree                              0.9.4
# ruamel-yaml                        0.15.87
# scikit-image                       0.17.2
# scikit-learn                       0.23.2
# scipy                              1.5.2
# seaborn                            0.11.0
# Send2Trash                         1.5.0
# setuptools                         50.3.1.post20201107
# simplegeneric                      0.8.1
# singledispatch                     3.4.0.3
# sip                                4.19.13
# six                                1.15.0
# snowballstemmer                    2.0.0
# sortedcollections                  1.2.1
# sortedcontainers                   2.2.2
# SoundFile                          0.10.3.post1
# soupsieve                          2.0.1
# Sphinx                             3.2.1
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             1.0.3
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.4
# sphinxcontrib-websupport           1.2.4
# spyder                             4.1.5
# spyder-kernels                     1.9.4
# SQLAlchemy                         1.3.20
# statsmodels                        0.12.0
# sympy                              1.6.2
# tables                             3.6.1
# tblib                              1.7.0
# terminado                          0.9.1
# testpath                           0.4.4
# threadpoolctl                      2.1.0
# tifffile                           2020.10.1
# toml                               0.10.1
# toolz                              0.11.1
# tornado                            6.0.4
# tqdm                               4.50.2
# traitlets                          5.0.5
# typing-extensions                  3.7.4.3
# ujson                              4.0.1
# unicodecsv                         0.14.1
# urllib3                            1.25.11
# watchdog                           0.10.3
# wcwidth                            0.2.5
# webencodings                       0.5.1
# Werkzeug                           1.0.1
# wheel                              0.35.1
# widgetsnbextension                 3.5.1
# win-inet-pton                      1.1.0
# win-unicode-console                0.5
# wincertstore                       0.2
# wrapt                              1.11.2
# xlrd                               1.2.0
# XlsxWriter                         1.3.7
# xlwings                            0.20.8
# xlwt                               1.3.0
# xmltodict                          0.12.0
# yapf                               0.30.0
# zict                               2.0.0
# zipp                               3.4.0
# zope.event                         4.5.0
# zope.interface                     5.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip uninstall -y libarchive-c
# Out:
# Found existing installation: libarchive-c 4.0
# Uninstalling libarchive-c-4.0:
#   Successfully uninstalled libarchive-c-4.0

# %%
import librosa

# %%
pip install libarchive-c

# %%
pip install librosa
# Out:
# Requirement already satisfied: librosa in c:\users\gflab\anaconda3\lib\site-packages (0.9.2)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\gflab\anaconda3\lib\site-packages (from librosa) (1.5.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\gflab\anaconda3\lib\site-packages (from librosa) (20.4)
# Requirement already satisfied: scikit-learn>=0.19.1 in c:\users\gflab\anaconda3\lib\site-packages (from librosa) (0.23.2)
# Requirement already satisfied: soundfile>=0.10.2 in c:\users\gflab\anaconda3\lib\site-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\gflab\anaconda3\lib\site-packages (from librosa) (3.0.0)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\gflab\anaconda3\lib\site-packages (from librosa) (1.23.3)
# Requirement already satisfied: numba>=0.45.1 in c:\users\gflab\anaconda3\lib\site-packages (from librosa) (0.56.2)
# Requirement already satisfied: joblib>=0.14 in c:\users\gflab\anaconda3\lib\site-packages (from librosa) (0.17.0)
# Requirement already satisfied: resampy>=0.2.2 in c:\users\gflab\anaconda3\lib\site-packages (from librosa) (0.4.0)
# Requirement already satisfied: decorator>=4.0.10 in c:\users\gflab\anaconda3\lib\site-packages (from librosa) (4.4.2)
# Requirement already satisfied: pooch>=1.0 in c:\users\gflab\anaconda3\lib\site-packages (from librosa) (1.6.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\gflab\anaconda3\lib\site-packages (from packaging>=20.0->librosa) (2.4.7)
# Requirement already satisfied: six in c:\users\gflab\anaconda3\lib\site-packages (from packaging>=20.0->librosa) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\gflab\anaconda3\lib\site-packages (from scikit-learn>=0.19.1->librosa) (2.1.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\gflab\anaconda3\lib\site-packages (from soundfile>=0.10.2->librosa) (1.14.3)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\gflab\anaconda3\lib\site-packages (from numba>=0.45.1->librosa) (0.39.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.9" in c:\users\gflab\anaconda3\lib\site-packages (from numba>=0.45.1->librosa) (4.12.0)
# Requirement already satisfied: setuptools<60 in c:\users\gflab\anaconda3\lib\site-packages (from numba>=0.45.1->librosa) (50.3.1.post20201107)
# Requirement already satisfied: requests>=2.19.0 in c:\users\gflab\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (2.24.0)
# Requirement already satisfied: appdirs>=1.3.0 in c:\users\gflab\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: pycparser in c:\users\gflab\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.20)
# Requirement already satisfied: zipp>=0.5 in c:\users\gflab\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.9"->numba>=0.45.1->librosa) (3.4.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\gflab\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gflab\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\gflab\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\gflab\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.25.11)
# Note: you may need to restart the kernel to use updated packages.
